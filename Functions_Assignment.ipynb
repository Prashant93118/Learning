# %%
#Ques1 What is the difference between a function and a method in Python?
#Ans- Function: A function is a block of code that performs a specific task. It can be called from anywhere in the program.
       #Method: A method is a function that is associated with an object. It can only be called from the object to which it is associated.

# %%
#Ques2 Explain the concept of function arguments and parameters in Python.
#Ans Arguments are values that are passed to a function when it is called.
#Parameters are variables that are declared in the function definition.

# %%
#Ques3 What are the different ways to define and call a function in Python?
#Ans A function can be defined using the def keyword.
#It can be called by its name followed by parentheses.

# %%
#Ques4 What is the purpose of the `return` statement in a Python function?
#Ans The return statement returns a value from a function.

# %%
#Ques5 What are iterators in Python and how do they differ from iterables?
#Ans An iterator constitutes an entity that facilitates the traversal of a sequence.
#An iterable is an object that can be iterated over.

# %%
#Ques6 Explain the concept of generators in Python and how they are defined.+
#Ans A generator is a special kind of function that uses the yield keyword to return a value.

# %%
#Ques7 What are the advantages of using generators over regular functions?
#Ans Generators are more memory-efficient, they can be used to generate sequences of values on demand.

# %%
#Ques8 What is a lambda function in Python and when is it typically used?
#Ans A lambda function is a small, anonymous function.
#It is typically used when you need a function for a short period of time without the need to formally define a function using def keyword.

# %%
#Ques9 Explain the purpose and usage of the map() function in Python.
#Ans he map() function applies a function to each item in an iterable.
#It can be used to transform sequences of values.

# %%
#Ques10 What is the difference between map(), reduce(), and filter() functions in Python?
#Ans The map() function applies a function to each item in an iterable.
#The reduce() function applies a function to pairs of items in an iterable.
#The filter() constructs an iterator from elements of an iterable for which a given function returns True. It takes two arguments: a function and an iterable.

# %%
#Ques11 Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13];

# %%
from functools import reduce

# %%
given_list = [47,11,42,13]
reduce(lambda x,y : x+y, given_list)
# Out:
# 113

# %% [markdown]
# ![function.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Practicle Questions**

# %%
#Ques1 Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
#Ans
numbers = [2,3,4,5,6,7,8]
def sum_even_numbers(numbers):
    sum_even = 0
    for num in numbers:
        if num % 2 == 0:
            sum_even += num
    return sum_even

# %%
sum_even_numbers(numbers)
# Out:
# 20

# %%
#Ques2  Create a Python function that accepts a string and returns the reverse of that string.
#Ans
def reverse_string(string):
    return string[::-1]

# %%
reverse_string("Pwskills")
# Out:
# 'sllikswP'

# %%
#Ques3 Implement a Python function that takes a list of integers and returns a new list containing the squares of each number
#Ans
l = [1,2,3,4]
def square(l):
  sq = []
  for i in l:
    sq.append(i**2)
  return sq

# %%
square(l)
# Out:
# [1, 4, 9, 16]

# %%
#Ques4  Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

# %%
is_prime(11)
# Out:
# True

# %%
#Ques5  Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
#Ans concept is not clear

# %%
#Ques6 Write a generator function in Python that yields the powers of 2 up to a given exponent.
#Ans
def powers_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

n = 6
for power in powers_of_two(n):
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64

# %%
#Ques7 Implement a generator function that reads a file line by line and yields each line as a string.
#Ans Totally confused that how to write a code.

# %%
#Ques8 Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
#Ans
data = [(1, 'banana'), (2, 'apple'), (3, 'cherry'), (4, 'date')]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)
# Out:
# [(2, 'apple'), (1, 'banana'), (3, 'cherry'), (4, 'date')]

# %%
#Ques9  Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
#Ans
temp_list = [10,20,30]
def celsius_to_fahrenheit(temp_list):
    return (temp_list * 9/5) + 32

temp_list = [10,20,30]
fahrenheit_temps = list(map(celsius_to_fahrenheit, temp_list))

# %%
celsius_to_fahrenheit(20)
# Out:
# 68.0

# %%
#Ques10 Create a Python program that uses `filter()` to remove all the vowels from a given string.
#Ans
def remove_vowels(string):
    vowels = 'aeiouAEIOU'
    filtered_string = ''.join(filter(lambda x: x not in vowels, string))
    return filtered_string

# %%
remove_vowels("Data Analytics")
# Out:
# 'Dt nlytcs'
